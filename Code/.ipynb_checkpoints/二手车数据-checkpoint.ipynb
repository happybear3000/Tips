# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "second_cars_info.csv"
data = pd.read_csv(path,encoding='gbk')

# %%
data.head(10)
# Out:
#   Brand                                 Name Boarding_time        Km  \
# 0    奥迪              奥迪A6L 2006款 2.4 CVT 舒适型       2006年8月   9.00万公里
# 1    奥迪              奥迪A6L 2007款 2.4 CVT 舒适型       2007年1月   8.00万公里
# 2    奥迪               奥迪A6L 2004款 2.4L 技术领先型       2005年5月  15.00万公里
# 3    奥迪       奥迪A8L 2013款 45 TFSI quattro舒适型      2013年10月   4.80万公里
# 4    奥迪               奥迪A6L 2014款 30 FSI 豪华型       2014年9月   0.81万公里
# 5    奥迪    奥迪R8 2014款 Spyder 5.2 FSI quattro           未上牌   0.03万公里
# 6    奥迪                 奥迪A6 2013款 40 hybrid       2014年8月   1.60万公里
# 7    奥迪                   奥迪S6 2013款 4.0TFSI       2014年9月   1.60万公里
# 8    奥迪                奥迪A7 2011款 2.8 自动 进取型       2013年7月   3.00万公里
# 9    奥迪  奥迪RS 5 2012款 4.2L 双离合 quattro Coupe       2013年5月   7.00万公里
#
#   Discharge  Sec_price New_price
# 0        国3       6.90    50.89万
# 1        国4       8.88    50.89万
# 2        国2       3.82    54.24万
# 3        欧4      44.80   101.06万
# 4     国4,国5      33.19    54.99万
# 5     国4,京5     169.00   273.86万
# 6     国4,京5      36.99    69.25万
# 7        欧5      59.99   114.84万
# 8        欧4      37.99    79.02万
# 9     国4,国5      56.80   130.04万

# %%
#数据结构
data.shape
# Out:
# (11281, 7)

# %%
#数据表格列名
data.columns
# Out:
# Index(['Brand', 'Name', 'Boarding_time', 'Km', 'Discharge', 'Sec_price',
#        'New_price'],
#       dtype='object')

# %%
#查看每一个品牌的数据量
data.Brand.value_counts()
# Out:
# 别克      1350
# 大众       991
# 奔驰       895
# 宝马       773
# 奥迪       758
#         ...
# 北京         1
# 东风风光       1
# 北汽制造       1
# WEY        1
# 腾势         1
# Name: Brand, Length: 104, dtype: int64

# %%
#查看上牌时间列不合规数据
data.Boarding_time
# Out:
# 0         2006年8月
# 1         2007年1月
# 2         2005年5月
# 3        2013年10月
# 4         2014年9月
#            ...
# 11276     2016年6月
# 11277     2011年6月
# 11278    2007年10月
# 11279    2011年12月
# 11280     2014年4月
# Name: Boarding_time, Length: 11281, dtype: object

# %%
data.Boarding_time.value_counts()
# Out:
# 2010年8月     223
# 2010年6月     200
# 2010年5月     172
# 2010年11月    164
# 2011年6月     160
#            ...
# 2003年5月       1
# 2002年4月       1
# 2002年11月      1
# 2003年2月       1
# 2001年9月       1
# Name: Boarding_time, Length: 188, dtype: int64

# %%
#未上牌车辆记录比例
N = np.sum(data.Boarding_time == "未上牌")
ratio = N / data.shape[0]
ratio
# Out:
# 0.00824395000443223

# %%
#删除“未上牌”记录，序列号变成不连续
data = data[data.Boarding_time != "未上牌"]

# %%
#处理索引，使其连续
data.index = np.arange(0,data.shape[0])
data.head(10)
# Out:
#   Brand                                 Name Boarding_time        Km  \
# 0    奥迪              奥迪A6L 2006款 2.4 CVT 舒适型       2006年8月   9.00万公里
# 1    奥迪              奥迪A6L 2007款 2.4 CVT 舒适型       2007年1月   8.00万公里
# 2    奥迪               奥迪A6L 2004款 2.4L 技术领先型       2005年5月  15.00万公里
# 7    奥迪                奥迪A7 2011款 2.8 自动 进取型       2013年7月   3.00万公里
# 8    奥迪  奥迪RS 5 2012款 4.2L 双离合 quattro Coupe       2013年5月   7.00万公里
# 9    奥迪     奥迪R8 2016款 V10 Coupe Performance       2017年8月   0.24万公里
#
#   Discharge  Sec_price New_price  year  month
# 0        国3       6.90    50.89万  2006      8
# 1        国4       8.88    50.89万  2007      1
# 2        国2       3.82    54.24万  2005      5
# 3        欧4      44.80   101.06万  2013     10
# 4     国4,国5      33.19    54.99万  2014      9
# 5     国4,京5      36.99    69.25万  2014      8
# 6        欧5      59.99   114.84万  2014      9
# 7        欧4      37.99    79.02万  2013      7
# 8     国4,国5      56.80   130.04万  2013      5
# 9        国5     229.90   275.49万  2017      8

# %%
#新增一列，计算上牌时间距离2017年10月的总月份数
data['diff_month'] = (2017-data.year)*12 + (10 - data.month)
data.head(10)
# Out:
#   Brand                                 Name Boarding_time        Km  \
# 0    奥迪              奥迪A6L 2006款 2.4 CVT 舒适型       2006年8月   9.00万公里
# 1    奥迪              奥迪A6L 2007款 2.4 CVT 舒适型       2007年1月   8.00万公里
# 2    奥迪               奥迪A6L 2004款 2.4L 技术领先型       2005年5月  15.00万公里
# 3    奥迪       奥迪A8L 2013款 45 TFSI quattro舒适型      2013年10月   4.80万公里
# 4    奥迪               奥迪A6L 2014款 30 FSI 豪华型       2014年9月   0.81万公里
# 5    奥迪                 奥迪A6 2013款 40 hybrid       2014年8月   1.60万公里
# 6    奥迪                   奥迪S6 2013款 4.0TFSI       2014年9月   1.60万公里
# 7    奥迪                奥迪A7 2011款 2.8 自动 进取型       2013年7月   3.00万公里
# 8    奥迪  奥迪RS 5 2012款 4.2L 双离合 quattro Coupe       2013年5月   7.00万公里
# 9    奥迪     奥迪R8 2016款 V10 Coupe Performance       2017年8月   0.24万公里
#
#   Discharge  Sec_price New_price  year  month  diff_month
# 0        国3       6.90    50.89万  2006      8         134
# 1        国4       8.88    50.89万  2007      1         129
# 2        国2       3.82    54.24万  2005      5         149
# 3        欧4      44.80   101.06万  2013     10          48
# 4     国4,国5      33.19    54.99万  2014      9          37
# 5     国4,京5      36.99    69.25万  2014      8          38
# 6        欧5      59.99   114.84万  2014      9          37
# 7        欧4      37.99    79.02万  2013      7          51
# 8     国4,国5      56.80   130.04万  2013      5          53
# 9        国5     229.90   275.49万  2017      8           2

# %%
#去掉汉字保留数字
data["Km_number"] = data.Km.str[:-3]

# %%
#转换时报错，发现除“万公里”字符串外，还有字符串“百公里内”
data["Km_number"] = data.Km_number.astype("float")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-f73d2da93862> in <module>()
#       1 #转换时报错，发现除“万公里”字符串外，还有字符串“百公里内”
# ----> 2 data["Km_number"] = data.Km_number.astype("float")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     557
#     558     def astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
# --> 559         return self._astype(dtype, copy=copy, errors=errors, values=values, **kwargs)
#     560
#     561     def _astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     641                     # _astype_nansafe works fine with 1-d only
#     642                     vals1d = values.ravel()
# --> 643                     values = astype_nansafe(vals1d, dtype, copy=True, **kwargs)
#     644
#     645                 # TODO(extension)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     727     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     728         # Explicit copy, or required since NumPy can't view from / to object.
# --> 729         return arr.astype(dtype, copy=True)
#     730
#     731     return arr.view(dtype)
#
# ValueError: could not convert string to float: '百'

# %%
#去掉含“百公里内”字符串数据
data = data[~(data.Km_number.str.contains("百"))]
index = data[~(data.Km_number.str.contains("百"))].index
data = data.loc[index,:]

# %%
#转换成浮点数
data["Km_number"] = data.Km_number.astype("float")

# %%
data.head(10)
# Out:
#   Brand                                 Name Boarding_time        Km  \
# 0    奥迪              奥迪A6L 2006款 2.4 CVT 舒适型       2006年8月   9.00万公里
# 1    奥迪              奥迪A6L 2007款 2.4 CVT 舒适型       2007年1月   8.00万公里

# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-bf644afdd0e6> in <module>()
#       1 #转换时，发现还包含字符串“暂无报价”
# ----> 2 data.New_price_number.astype("float")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     557
#     558     def astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
# --> 559         return self._astype(dtype, copy=copy, errors=errors, values=values, **kwargs)
#     560
#     561     def _astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     641                     # _astype_nansafe works fine with 1-d only
#     642                     vals1d = values.ravel()
# --> 643                     values = astype_nansafe(vals1d, dtype, copy=True, **kwargs)
#     644
#     645                 # TODO(extension)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     727     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     728         # Explicit copy, or required since NumPy can't view from / to object.
# --> 729         return arr.astype(dtype, copy=True)
#     730
#     731     return arr.view(dtype)
#
# ValueError: could not convert string to float: '暂'

# %%
data = data.loc[data.New_price != "暂无",:]#消除含“暂无报价”字符串的数据
data.New_price_number.astype("float")
# Out:
# 0         50.89
# 1         50.89
# 2         54.24
# 3        101.06
# 4         54.99
#           ...
# 11183      9.63
# 11184      6.22
# 11185     11.48
# 11186      8.99
# 11187    168.25
# Name: New_price_number, Length: 10984, dtype: float64

# %%
data.head(10)
# Out:
#   Brand                                 Name Boarding_time        Km  \
# 0    奥迪              奥迪A6L 2006款 2.4 CVT 舒适型       2006年8月   9.00万公里
# 1    奥迪              奥迪A6L 2007款 2.4 CVT 舒适型       2007年1月   8.00万公里
# 2    奥迪               奥迪A6L 2004款 2.4L 技术领先型       2005年5月  15.00万公里
# 3    奥迪       奥迪A8L 2013款 45 TFSI quattro舒适型      2013年10月   4.80万公里
# 4    奥迪               奥迪A6L 2014款 30 FSI 豪华型       2014年9月   0.81万公里
# 5    奥迪                 奥迪A6 2013款 40 hybrid       2014年8月   1.60万公里
# 6    奥迪                   奥迪S6 2013款 4.0TFSI       2014年9月   1.60万公里
# 7    奥迪                奥迪A7 2011款 2.8 自动 进取型       2013年7月   3.00万公里
# 8    奥迪  奥迪RS 5 2012款 4.2L 双离合 quattro Coupe       2013年5月   7.00万公里
# 9    奥迪     奥迪R8 2016款 V10 Coupe Performance       2017年8月   0.24万公里
#
#   Discharge  Sec_price New_price  year  month  diff_month  Km_number  \
# 0        国3       6.90    50.89万  2006      8         134       9.00
# 1        国4       8.88    50.89万  2007      1         129       8.00
# 2        国2       3.82    54.24万  2005      5         149      15.00
# 3        欧4      44.80   101.06万  2013     10          48       4.80
# 4     国4,国5      33.19    54.99万  2014      9          37       0.81
# 5     国4,京5      36.99    69.25万  2014      8          38       1.60
# 6        欧5      59.99   114.84万  2014      9          37       1.60
# 7        欧4      37.99    79.02万  2013      7          51       3.00
# 8     国4,国5      56.80   130.04万  2013      5          53       7.00
# 9        国5     229.90   275.49万  2017      8           2       0.24
#
#   New_price_number
# 0            50.89
# 1            50.89
# 2            54.24
# 3           101.06
# 4            54.99
# 5            69.25
# 6           114.84
# 7            79.02
# 8           130.04
# 9           275.49

# %%
data.Sec_price.value_counts()
# Out:
# 4.50     91
# 4.80     83
# 8.80     79
# 5.50     75
# 4.88     72
#          ..
# 10.45     1
# 4.67      1
# 16.55     1
# 18.85     1
# 15.10     1
# Name: Sec_price, Length: 1899, dtype: int64

# %%
Sec_price_min = data.Sec_price.min()
Sec_price_max = data.Sec_price.max()
price_cut = pd.cut(data.Sec_price,bins = [Sec_price_min,3,5,8,10,15,20,30,45,100,Sec_price_max])
price_state = price_cut.value_counts() #不同价格区间车的台数
price_state
# Out:
# (5.0, 8.0]        1956
# (3.0, 5.0]        1790
# (10.0, 15.0]      1307
# (20.0, 30.0]      1090
# (15.0, 20.0]       979
# (8.0, 10.0]        914
# (45.0, 100.0]      844
# (30.0, 45.0]       823
# (0.65, 3.0]        810
# (100.0, 808.0]     468
# Name: Sec_price, dtype: int64

# %%
#画图

plt.rcParams['font.sans-serif'] = ['Microsoft YeHei']
plt.rcParams['axes.unicode_minus'] = False
x = np.arange(len(price_state)) #有几根柱子
y = price_state #每根柱子对应的二手车数量
plt.figure(figsize = (8,6)) #画布大小
plt.bar(x,y,color = "steelblue",alpha = 0.8) #画图
plt.xticks(np.arange(len(price_state)),price_state.index,rotation = 45)
plt.xlabel("价格区间")
plt.ylabel("频数")
plt.title("二手车价格分布图")
plt.ylim([0,2200])
percents = [str(round(i*100,2)) + "%" for i in price_state / price_state.sum()]
for x,y,z in zip(x,y,percents):
    plt.text(x-0.4,y+50,z) # 百分数位置修正
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-f22793de56f8> in <module>()
#      12 plt.title("二手车价格分布图")
#      13 plt.ylim([0,2200])
# ---> 14 percents = [str(round(i*100,2)) + "%" for i in price_state / price_state.sum()]
#      15 for x,y,z in zip(x,y,percents):
#      16     plt.text(x-0.4,y+50,z)
#
# <ipython-input-72-f22793de56f8> in <listcomp>(.0)
#      12 plt.title("二手车价格分布图")
#      13 plt.ylim([0,2200])
# ---> 14 percents = [str(round(i*100,2)) + "%" for i in price_state / price_state.sum()]
#      15 for x,y,z in zip(x,y,percents):
#      16     plt.text(x-0.4,y+50,z)
#
# TypeError: 'str' object is not callable
# /Users/edward/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#分析价格和行驶时长，路程的关系
data.diff_month

# %%
index = data['Brand'].isin(['奥迪','大众'])
somecars = data.loc[index,:]
somecars.head()
# Out:
#   Brand                            Name Boarding_time        Km Discharge  \
# 0    奥迪         奥迪A6L 2006款 2.4 CVT 舒适型       2006年8月   9.00万公里        国3
# 1    奥迪         奥迪A6L 2007款 2.4 CVT 舒适型       2007年1月   8.00万公里        国4
# 2    奥迪          奥迪A6L 2004款 2.4L 技术领先型       2005年5月  15.00万公里        国2
# 3    奥迪  奥迪A8L 2013款 45 TFSI quattro舒适型      2013年10月   4.80万公里        欧4
# 4    奥迪          奥迪A6L 2014款 30 FSI 豪华型       2014年9月   0.81万公里     国4,国5
#
#    Sec_price New_price  Km_number New_price_number
# 0       6.90    50.89万       9.00            50.89
# 1       8.88    50.89万       8.00            50.89
# 2       3.82    54.24万      15.00            54.24
# 3      44.80   101.06万       4.80           101.06
# 4      33.19    54.99万       0.81            54.99

# %%
#画图

plt.rcParams['font.sans-serif'] = ['Microsoft YeHei']
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize = (12,10)) #画布大小
brands_e = ['奥迪','大众']
colors = ['steelblue','#ff9999']
for i in range(len(brands_e)):
    plt.scatter(somecars[somecars['Brand'] == brands_e[i]]['Km_number'],
                somecars[somecars['Brand'] == brands_e[i]]['diff_month'],
                s = (somecars[somecars['Brand'] == brands_e[i]]['Sec_price']*2), #设置点的大小
                c = colors[i], #设置点的颜色
                alpha = 0.8,
                marker  = 'o') #设置点的形状
plt.legend(scatterpoints = 1 , markerscale = 0.6)
plt.xlabel("使用时长（月）")
plt.ylabel("公里数（公里）")
plt.title("二手车价格分布图")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'diff_month'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-4cd73163847b> in <module>()
#       8 for i in range(len(brands_e)):
#       9     plt.scatter(somecars[somecars['Brand'] == brands_e[i]]['Km_number'],
# ---> 10                 somecars[somecars['Brand'] == brands_e[i]]['diff_month'],
#      11                 s = (somecars[somecars['Brand'] == brands_e[i]]['Sec_price']*2), #设置点的大小
#      12                 c = colors[i], #设置点的颜色
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'diff_month'
